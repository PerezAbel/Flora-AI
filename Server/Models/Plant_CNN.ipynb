# %%
# !pip install tensorflow

# %%
import zipfile

zip_path = '/content/Multi-Crop Disease Dataset.zip'

try:
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        print(f"'{zip_path}' is a valid zip file.")
except zipfile.BadZipFile:
    print(f"Error: '{zip_path}' is not a valid zip file or is corrupted.")
except FileNotFoundError:
    print(f"Error: The file '{zip_path}' was not found.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Error: '/content/Multi-Crop Disease Dataset.zip' is not a valid zip file or is corrupted.

# %%
trainpath = r"/content/Multi-Crop Disease Dataset/Train/"
testpath = r"/content/Multi-Crop Disease Dataset/Test/"
predpath = r"/content/Multi-Crop Disease Dataset/"

# %%
import os

dataset_base_path_to_check = '/content/drive/MyDrive/Multi-Crop Disease Dataset/Multicrop Disease Dataset/Multicrop Disease Dataset'

if os.path.exists(dataset_base_path_to_check):
    print(f"The directory '{dataset_base_path_to_check}' exists.")
    print("Contents of the directory:")
    for item in os.listdir(dataset_base_path_to_check):
        print(f"  - {item}")

    # Further check for common subdirectories like 'Train' and 'Test'
    if os.path.exists(os.path.join(dataset_base_path_to_check, 'Train')):
        print("'Train' subdirectory found.")
    else:
        print("'Train' subdirectory NOT found.")

    if os.path.exists(os.path.join(dataset_base_path_to_check, 'Test')):
        print("'Test' subdirectory found.")
    else:
        print("'Test' subdirectory NOT found.")

    if os.path.exists(os.path.join(dataset_base_path_to_check, 'train')):
        print("'train' subdirectory found.")
    else:
        print("'train' subdirectory NOT found.")

    if os.path.exists(os.path.join(dataset_base_path_to_check, 'test')):
        print("'test' subdirectory found.")
    else:
        print("'test' subdirectory NOT found.")

    if os.path.exists(os.path.join(dataset_base_path_to_check, 'val')):
        print("'val' subdirectory found.")
    else:
        print("'val' subdirectory NOT found.")

else:
    print(f"Error: The directory '{dataset_base_path_to_check}' does not exist. Please ensure the dataset is unzipped into this location.")
# Out:
# The directory '/content/drive/MyDrive/Multi-Crop Disease Dataset/Multicrop Disease Dataset/Multicrop Disease Dataset' exists.
# Contents of the directory:
#   - README.roboflow.txt
#   - data.yaml
#   - test
#   - train
#   - valid
# 'Train' subdirectory NOT found.
# 'Test' subdirectory NOT found.
# 'train' subdirectory found.
# 'test' subdirectory found.
# 'val' subdirectory NOT found.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
trainpath = r"/content/drive/MyDrive/Multi-Crop Disease Dataset/Multicrop Disease Dataset/Multicrop Disease Dataset/train"
testpath = r"/content/drive/MyDrive/Multi-Crop Disease Dataset/Multicrop Disease Dataset/Multicrop Disease Dataset/test"
predpath = r"/content/drive/MyDrive/Multi-Crop Disease Dataset/Multicrop Disease Dataset/Multicrop Disease Dataset/valid"

# %%
import glob as gb
import os

print(f"Checking contents of: {trainpath}")
for folder in os.listdir(trainpath):
    full_folder_path = os.path.join(trainpath, folder);
    print(f"  - Found item: {folder} (at {full_folder_path})")
    if os.path.isdir(full_folder_path):
        contents = os.listdir(full_folder_path)
        print(f"    - Contents of '{folder}': {contents[:5]}... (showing first 5 items if any)")
        files = gb.glob(os.path.join(full_folder_path, '*.*'))
        print(f'    - For training data, found {len(files)} files in folder {full_folder_path}')
    else:
        print(f"    - {folder} is a file, not a directory.")
# Out:
# Checking contents of: /content/drive/MyDrive/Multi-Crop Disease Dataset/Multicrop Disease Dataset/Multicrop Disease Dataset/train
#   - Found item: images (at /content/drive/MyDrive/Multi-Crop Disease Dataset/Multicrop Disease Dataset/Multicrop Disease Dataset/train/images)
#     - Contents of 'images': ['Yellow-and-Black-Sigatoka-2083-_jpg.rf.2de0d6b0b6b471ad206c7f19a91ca32c.jpg', 'Yellow-and-Black-Sigatoka-2018-_jpg.rf.0f7226fb4c81de8a06f5e39312853962.jpg', 'Yellow-and-Black-Sigatoka-2077-_jpg.rf.751feaddff2f9f4547cc98c8744ff7be.jpg', 'Yellow-and-Black-Sigatoka-2019-_jpg.rf.901ac1a4099092361e280e66cb4873d0.jpg', 'Yellow-and-Black-Sigatoka-1898-_jpg.rf.43b2be3959bc95bfffa175c0db561354.jpg']... (showing first 5 items if any)
#     - For training data, found 15310 files in folder /content/drive/MyDrive/Multi-Crop Disease Dataset/Multicrop Disease Dataset/Multicrop Disease Dataset/train/images
# ...

# %%
import glob as gb
import os
for folder in os.listdir(testpath):
    files = gb.glob(os.path.join(testpath, folder, '*.*'))
    print(f'For testing data, found {len(files)} in folder {folder}')
# Out:
# For testing data, found 2191 in folder images
# For testing data, found 2191 in folder labels

# %%
import glob as gb
import os
import cv2
import pandas as pd

size = []
for folder in os.listdir(trainpath):
    files = gb.glob(pathname=os.path.join(trainpath, folder, '*.*'))
    for file in files:
        try:
            image = cv2.imread(file)
            if image is not None:
                size.append(image.shape)
            else:
                print(f"Failed to load {file}: Image is None")
        except Exception as e:
            print(f"Error reading {file}: {e}")
size_counts = pd.Series(size).value_counts()
print(size_counts)
# Out:
# Streaming output truncated to the last 5000 lines.
# Failed to load /content/drive/MyDrive/Multi-Crop Disease Dataset/Multicrop Disease Dataset/Multicrop Disease Dataset/train/labels/IMG-110-_jpg.rf.6c3eb94227eb8c223f8b1c3c76c79cab.txt: Image is None
# Failed to load /content/drive/MyDrive/Multi-Crop Disease Dataset/Multicrop Disease Dataset/Multicrop Disease Dataset/train/labels/IMG-112-_jpg.rf.936ea5e7c47b055257957a0b273067a9.txt: Image is None
# Failed to load /content/drive/MyDrive/Multi-Crop Disease Dataset/Multicrop Disease Dataset/Multicrop Disease Dataset/train/labels/IMG-130-_jpg.rf.8092fedd4148926e95e8f5b9ec154714.txt: Image is None
# Failed to load /content/drive/MyDrive/Multi-Crop Disease Dataset/Multicrop Disease Dataset/Multicrop Disease Dataset/train/labels/IMG-117-_jpeg.rf.d284088ff076049c700e4749044ed49d.txt: Image is None
# ...

# %%
import glob as gb
import os
import cv2
import pandas as pd

size = []
for folder in os.listdir(testpath):
    files = gb.glob(pathname=os.path.join(testpath, folder, '*.*'))
    for file in files:
        try:
            image = cv2.imread(file)
            if image is not None:
                size.append(image.shape)
            else:
                print(f"Failed to load {file}: Image is None")
        except Exception as e:
            print(f"Error reading {file}: {e}")

size_counts = pd.Series(size).value_counts()
print(size_counts)
# Out:
# (640, 640, 3)    2191
# Name: count, dtype: int64

# %%
X_train = []
y_train = []
for folder in os.listdir(trainpath):
    files = gb.glob(pathname=str(trainpath + folder + '/*.*'))
    for file in files:
        image = cv2.imread(file)
        image_array = cv2.resize(image, (s,s))
        X_train.append(list(image_array))
        y_train.append(code[folder])

# %%
X_test = []
y_test = []
for folder in os.listdir(testpath):
    files = gb.glob(pathname=str(testpath + folder + '/*.*'))
    for file in files:
        image = cv2.imread(file)
        image_array = cv2.resize(image, (s,s))
        X_test.append(list(image_array))
        y_test.append(code[folder])

# %%
# %pip install tensorflow numpy matplotlib opencv-python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="whitegrid")
import os
import glob as gb
import cv2
import tensorflow as tf
import keras

# %%
trainpath = r"
testpath = r"/content/drive/MyDrive/Multi-Crop Disease Dataset/Test/"
predpath = r"/content/drive/MyDrive/Multi-Crop Disease Dataset/"
# Out:
#   File "/tmp/ipykernel_11963/2554180379.py", line 1
#     trainpath = r"
#                 ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
for folder in os.listdir(trainpath) :
    files = gb.glob(str(trainpath + folder + '/*.*'))
    print(f'For training data , found {len(files)} in folder {folder}')

# %%
for folder in os.listdir(testpath) :
    files = gb.glob(str(testpath + folder + '/*.*'))
    print(f'For testing data , found {len(files)} in folder {folder}')

# %%
import glob as gb
import os
files = gb.glob(os.path.join(predpath, '*.*'))
print(f'For Prediction data , found {len(files)}')

# %%
code	=	{'Healthy':0,'Powdery':1,'Rust':2}
def getcode(n) :
    for x , y in code.items() :
        if n == y :
            return x

# %%
import glob as gb
import os
import cv2
import pandas as pd

size = []
for folder in os.listdir(trainpath):
    files = gb.glob(pathname=os.path.join(trainpath, folder, '*.*'))
    for file in files:
        try:
            image = cv2.imread(file)
            if image is not None:
                size.append(image.shape)
            else:
                print(f"Failed to load {file}: Image is None")
        except Exception as e:
            print(f"Error reading {file}: {e}")
size_counts = pd.Series(size).value_counts()
print(size_counts)

# %%
import glob as gb
import os
import cv2
import pandas as pd

size = []
for folder in os.listdir(testpath):
    files = gb.glob(pathname=os.path.join(testpath, folder, '*.*'))
    for file in files:
        try:
            image = cv2.imread(file)
            if image is not None:
                size.append(image.shape)
            else:
                print(f"Failed to load {file}: Image is None")
        except Exception as e:
            print(f"Error reading {file}: {e}")

size_counts = pd.Series(size).value_counts()
print(size_counts)

# %%
import glob as gb
import os
import cv2
import pandas as pd

size = []
files = gb.glob(pathname=os.path.join(predpath, '*.*'))
for file in files:
    try:
        image = cv2.imread(file)
        if image is not None:
            size.append(image.shape)
        else:
            print(f"Failed to load {file}: Image is None")
    except Exception as e:
        print(f"Error reading {file}: {e}")

size_counts = pd.Series(size).value_counts()
print(size_counts)

# %%
s = 100

# %%
import glob as gb
import os
import cv2

X_train = []
y_train = []
for folder in  os.listdir(trainpath) :
    files = gb.glob(pathname=os.path.join(trainpath, folder, '*.*'))
    for file in files:
        image = cv2.imread(file)
        if image is not None:
            image_array = cv2.resize(image , (s,s))
            X_train.append(list(image_array))
            y_train.append(code[folder])

# %%
print(f'we have {len(X_train)} items in X_train')

# %%
plt.figure(figsize=(35,35))
for n , i in enumerate(list(np.random.randint(0,len(X_train),36))) :
    plt.subplot(6,6,n+1)
    plt.imshow(X_train[i])
    plt.axis('off')
    plt.title(getcode(y_train[i]))

# %%
import glob as gb
import os
import cv2

X_test = []
y_test = []
for folder in  os.listdir(testpath) :
    files = gb.glob(pathname=os.path.join(testpath, folder, '*.*'))
    for file in files:
        image = cv2.imread(file)
        if image is not None:
            image_array = cv2.resize(image , (s,s))
            X_test.append(list(image_array))
            y_test.append(code[folder])

# %%
print(f'we have {len(X_test)} items in X_test')

# %%
plt.figure(figsize=(20,20))
for n , i in enumerate(list(np.random.randint(0,len(X_test),36))) :
    plt.subplot(6,6,n+1)
    plt.imshow(X_test[i])
    plt.axis('off')
    plt.title(getcode(y_test[i]))

# %%
import glob as gb
import os
import cv2

X_pred = []
files = gb.glob(pathname=os.path.join(predpath, '*.*'))
for file in files:
    image = cv2.imread(file)
    if image is not None:
        image_array = cv2.resize(image , (s,s))
        X_pred.append(list(image_array))

# %%
print(f'we have {len(X_pred)} items in X_pred')

# %%
plt.figure(figsize=(35,35))
for n , i in enumerate(list(np.random.randint(0,len(X_pred),36))) :
    plt.subplot(6,6,n+1)
    plt.imshow(X_pred[i])
    plt.axis('off')

# %%
X_train = np.array(X_train)
X_test = np.array(X_test)
X_pred_array = np.array(X_pred)
y_train = np.array(y_train)
y_test = np.array(y_test)

print(f'X_train shape  is {X_train.shape}')
print(f'X_test shape  is {X_test.shape}')
print(f'X_pred shape  is {X_pred_array.shape}')
print(f'y_train shape  is {y_train.shape}')
print(f'y_test shape  is {y_test.shape}')

# %%
KerasModel	=keras.models.Sequential([
        keras.layers.Conv2D(200,kernel_size=(3,3),activation='relu',input_shape=(s,s,3)),
        keras.layers.Conv2D(150,kernel_size=(3,3),activation='relu'),
        keras.layers.MaxPool2D(4,4),
        keras.layers.Conv2D(120,kernel_size=(3,3),activation='relu'),
        keras.layers.Conv2D(80,kernel_size=(3,3),activation='relu'),
        keras.layers.Conv2D(50,kernel_size=(3,3),activation='relu'),
        keras.layers.MaxPool2D(4,4),
        keras.layers.Flatten()	,
        keras.layers.Dense(120,activation='relu')	,
        keras.layers.Dense(100,activation='relu')	,
        keras.layers.Dense(50,activation='relu')	,
        keras.layers.Dropout(rate=0.5)	,
        keras.layers.Dense(3,activation='softmax')	,
])

# %%
KerasModel.compile(optimizer ='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
print('Model Details are : ',KerasModel)
print(KerasModel.summary())

# %%
epochs = 50
ThisModel = KerasModel.fit(X_train, y_train, epochs=epochs,batch_size=64,verbose=1)

# %%
ModelLoss, ModelAccuracy = KerasModel.evaluate(X_test, y_test)

print('Test Loss is {}'.format(ModelLoss))
print('Test Accuracy is {}'.format(ModelAccuracy ))

# %%
y_pred = KerasModel.predict(X_test)

print('Prediction Shape is {}'.format(y_pred.shape))

# %%
y_result = KerasModel.predict(X_pred_array)

print('Prediction Shape is {}'.format(y_result.shape))

# %%
KerasModel.save('PR.h5')
